# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# URL of the new CSV file

df_new= pd.read_csv('../data/twitch_star.csv')

# %%
df_new.describe()
# Out:
#               RANK  AVERAGE_STREAM_DURATION  FOLLOWERS_GAINED_PER_STREAM  \
# count   999.000000               999.000000                   999.000000
# mean    500.972973                 5.996697                  3383.445445
# std     288.576373                 3.241013                  2742.696216
# min       1.000000                 1.200000                 -4240.000000
# 25%     251.500000                 4.200000                  1360.500000
# 50%     501.000000                 5.400000                  2450.000000
# 75%     750.500000                 6.900000                  4831.500000
# max    1000.000000                23.900000                 18889.000000
#
#        AVG_VIEWERS_PER_STREAM  AVG_GAMES_PER_STREAM  TOTAL_TIME_STREAMED  \
# count              999.000000            999.000000           999.000000
# mean             19595.082082              1.477878          6504.741742
# std              43241.584073              0.575189          6731.164111
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RANK                            999 non-null    int64
#  1   NAME                            999 non-null    object
#  2   LANGUAGE                        999 non-null    object
#  3   TYPE                            999 non-null    object
#  4   MOST_STREAMED_GAME              999 non-null    object
#  5   2ND_MOST_STREAMED_GAME          922 non-null    object
#  6   AVERAGE_STREAM_DURATION         999 non-null    float64
#  7   FOLLOWERS_GAINED_PER_STREAM     999 non-null    int64
#  8   AVG_VIEWERS_PER_STREAM          999 non-null    int64
#  9   AVG_GAMES_PER_STREAM            999 non-null    float64
#  10  TOTAL_TIME_STREAMED             999 non-null    int64
#  11  TOTAL_FOLLOWERS                 999 non-null    int64
# ...

# %%
print(df_new.columns)
# Out:
# Index(['RANK', 'NAME', 'LANGUAGE', 'TYPE', 'MOST_STREAMED_GAME',
#        '2ND_MOST_STREAMED_GAME', 'AVERAGE_STREAM_DURATION',
#        'FOLLOWERS_GAINED_PER_STREAM', 'AVG_VIEWERS_PER_STREAM',
#        'AVG_GAMES_PER_STREAM', 'TOTAL_TIME_STREAMED', 'TOTAL_FOLLOWERS',
#        'TOTAL_VIEWS', 'TOTAL_GAMES_STREAMED', 'ACTIVE_DAYS_PER_WEEK',
#        'MOST_ACTIVE_DAY', 'DAY_WITH_MOST_FOLLOWERS_GAINED'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)  # This will display all columns
print(df_new.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   RANK                            999 non-null    int64
#  1   NAME                            999 non-null    object
#  2   LANGUAGE                        999 non-null    object
#  3   TYPE                            999 non-null    object
#  4   MOST_STREAMED_GAME              999 non-null    object
#  5   2ND_MOST_STREAMED_GAME          922 non-null    object
#  6   AVERAGE_STREAM_DURATION         999 non-null    float64
#  7   FOLLOWERS_GAINED_PER_STREAM     999 non-null    int64
#  8   AVG_VIEWERS_PER_STREAM          999 non-null    int64
#  9   AVG_GAMES_PER_STREAM            999 non-null    float64
#  10  TOTAL_TIME_STREAMED             999 non-null    int64
#  11  TOTAL_FOLLOWERS                 999 non-null    int64
# ...

# %%
#TOP 10 STREAMED GAMES
top_streamed_games = df_new['MOST_STREAMED_GAME'].value_counts().head(10)

# Display the results
print("Top 10 Most Streamed Games:")
print(top_streamed_games)
# Out:
# Top 10 Most Streamed Games:
# MOST_STREAMED_GAME
# Just Chatting         257
# League of Legends      84
# Grand Theft Auto V     74
# VALORANT               60
# Casino                 36
# Fortnite               35
# Dota 2                 35
# Counter-Strike         31
# Minecraft              24
# Virtual Casino         23
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df' is your DataFrame and 'MOST_ACTIVE_DAY' is the time-related column (replace it with your actual time column)
# Ensure your time-related column is in datetime format if needed
# df['stream_date'] = pd.to_datetime(df['stream_date'])  # Uncomment if you have a stream_date column

# Step 1: Aggregate total views for each game over time (assuming MOST_ACTIVE_DAY represents the time period)
game_time_performance = df.groupby(['MOST_ACTIVE_DAY', 'MOST_STREAMED_GAME']).agg({
    'TOTAL_VIEWS': 'sum',
    'AVG_VIEWERS_PER_STREAM': 'mean',
    'FOLLOWERS_GAINED_PER_STREAM': 'mean',
    'TOTAL_FOLLOWERS': 'sum',
    'TOTAL_TIME_STREAMED': 'sum'
}).reset_index()

# Step 2: Aggregate total views across all time periods for each game
game_performance = game_time_performance.groupby('MOST_STREAMED_GAME').agg({
    'TOTAL_VIEWS': 'sum',
}).reset_index()

# Step 3: Sort and get the top 100 games based on total views
top_100_games = game_performance.sort_values(by='TOTAL_VIEWS', ascending=False).head(100)

# Step 4: Filter the game_time_performance DataFrame to include only the top 100 games
top_100_game_time_performance = game_time_performance[game_time_performance['MOST_STREAMED_GAME'].isin(top_100_games['MOST_STREAMED_GAME'])]

# Step 5: Plot the performance of top 100 games over time
plt.figure(figsize=(14, 8))
sns.lineplot(x='MOST_ACTIVE_DAY', y='TOTAL_VIEWS', data=top_100_game_time_performance, hue='MOST_STREAMED_GAME', legend=None, marker='o')
plt.title('Top 100 Most Streamed Games Over Time by Total Views')
plt.xlabel('Time (Most Active Day)')
plt.ylabel('Total Views')
plt.xticks(rotation=45)
plt.tight_layout()
plt.legend(title='Games', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3879279815.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title='Games', bbox_to_anchor=(1.05, 1), loc='upper left')

# %%
# Set the style for dark background
plt.style.use('dark_background')

# Plot the top 10 most streamed games
top_streamed_games.plot(kind='bar', figsize=(10, 6), color='#FF007F', edgecolor='white')

# Title and labels with white font color for contrast
plt.title('Top 10 Most Streamed Games', fontsize=16, color='white')
plt.xlabel('Game', fontsize=12, color='white')
plt.ylabel('Total Hours Streamed', fontsize=12, color='white')

# Set x-axis tick labels to rotate for better readability
plt.xticks(rotation=45, ha='right', color='white')

# Remove gridlines (optional for cleaner look)
plt.grid(False)

# Tight layout to ensure elements fit well within the figure
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Just Chatting on Twitch is a category where streamers broadcast live video to engage directly with their viewers through conversation, rather than playing video games or focusing on a specific activity.

# %% [markdown]
# Most people watch Just Chatting and IRL streams for chats, travel, or just like casual interactions.

# %%
top_languages = df_new['LANGUAGE'].value_counts().head(10)

# Display the top 10 languages
print(top_languages)
# Out:
# LANGUAGE
# English       401
# Russian       115
# Spanish       106
# Portuguese     82
# Japanese       79
# French         72
# German         60
# Chinese        28
# Polish         18
# Italian        13
# Name: count, dtype: int64

# %%
views_data = df_new[["NAME", "AVG_VIEWERS_PER_STREAM", "TOTAL_VIEWS"]]

# Display the top 10 streamers by average viewers
top_avg_viewers = views_data.sort_values(by="AVG_VIEWERS_PER_STREAM", ascending=False).head(10)
print("Top 10 Streamers by Average Viewers:")
print(top_avg_viewers)

# Display the top 10 streamers by total views
top_total_views = views_data.sort_values(by="TOTAL_VIEWS", ascending=False).head(10)
print("\nTop 10 Streamers by Total Views:")
print(top_total_views)
# Out:
# Top 10 Streamers by Average Viewers:
#              NAME  AVG_VIEWERS_PER_STREAM  TOTAL_VIEWS
# 206  twitchrivals                  481615    269000000
# 29     ow_esports                  400009    240000000
# 651      gcxevent                  387406     32000000
# 169      fortnite                  352166    110000000
# 46   rocketleague                  349645    312000000
# 8       riotgames                  346968      1339000
# 178           evo                  338908     53500000
# 289           att                  261664      8640000
# 910  echo_esports                  249671     23200000
# 23         gaules                  235565    405000000
#
# Top 10 Streamers by Total Views:
#            NAME  AVG_VIEWERS_PER_STREAM  TOTAL_VIEWS
# 269       ninja                   28075    572000000
# 30       shroud                   28744    571000000
# 20          xqc                  224584    525000000
# 39     summit1g                  162001    505000000
# ...

# %%
# Plot the top 10 languages
top_languages.plot(kind='bar', figsize=(10, 6), color='#FF007F')
plt.title('Top 10 Languages by Frequency')
plt.xlabel('Language')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The stacked bar plot shows the top 10 games and how their views are shared across the top 10 languages.It's very clear that English is the most dominant one.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Group by language and most streamed game, summing up total views
game_language_analysis = df_new.groupby(['LANGUAGE', 'MOST_STREAMED_GAME'])['TOTAL_VIEWS'].sum().unstack().fillna(0)

# Get the total views for each language (sum across all games)
total_views_per_language = game_language_analysis.sum(axis=1).sort_values(ascending=False)

# Select the top 10 most popular languages
top_10_languages = total_views_per_language.head(10)

# Filter the game_language_analysis to only include the top 10 languages
game_language_analysis_top_10 = game_language_analysis.loc[top_10_languages.index]

# Get the total views for each game in the filtered dataset
total_views_per_game = game_language_analysis_top_10.sum(axis=0).sort_values(ascending=False)

# Select the top 10 most popular games from the filtered dataset
top_10_games = total_views_per_game.head(10)

# Filter the data to include only the top 10 games
game_language_analysis_top_10_games = game_language_analysis_top_10[top_10_games.index]

# Transpose the data for better visualization
game_language_analysis_top_10_games = game_language_analysis_top_10_games.T

# Define custom electro color palette (neon-like colors)
electro_colors = ['#FF007F', '#8A2BE2', '#00FFFF', '#A9A9A9', '#8B00FF', '#FF1493', '#00BFFF', '#00FF7F', '#FF6347', '#FF4500']

# Identify the most popular game (the one with the highest total views)
most_popular_game = game_language_analysis_top_10_games.sum(axis=1).idxmax()

# Plot the top 10 games by the top 10 languages using a stacked bar plot
ax = game_language_analysis_top_10_games.plot(kind='bar', figsize=(12, 8), stacked=True, color=electro_colors)

# Highlight the most popular game with color #FF007F
for i, bar in enumerate(ax.patches):
    # Find which bar belongs to the most popular game
    if game_language_analysis_top_10_games.index[i // len(game_language_analysis_top_10_games.columns)] == most_popular_game:
        bar.set_facecolor('#FF007F')  # Set color for the most popular game

# Add titles and labels
plt.title('Top 10 Most Popular Games by Top 10 Languages', fontsize=16)
plt.xlabel('Game', fontsize=12)
plt.ylabel('Total Views', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Language', bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
top_streamers_by_followers = df_new.sort_values(by='TOTAL_FOLLOWERS', ascending=False).head(1000)
language_distribution_top_streamers = top_streamers_by_followers['LANGUAGE'].value_counts()
print(language_distribution_top_streamers)
# Out:
# LANGUAGE
# English       401
# Russian       115
# Spanish       106
# Portuguese     82
# Japanese       79
# French         72
# German         60
# Chinese        28
# Polish         18
# Italian        13
# Turkish         7
# Thai            5
# Czech           3
# Ukrainian       3
# Korean          2
# Cantonese       2
# Hungarian       1
# Arabic          1
# Romanian        1
# Name: count, dtype: int64

# %%
# Group by 'Game' and sum the 'Streamers' for each game
top_10_streamers = df_new.groupby('Game')['Streamers'].sum()

# Sort the games by the total 'Streamers' in descending order and get the top 10
top_10_streamers = top_10_streamers.sort_values(ascending=False).head(10)

# Plot the data
plt.style.use('dark_background')
top_10_streamers.plot(kind='bar', figsize=(10, 6), color='cyan', edgecolor='white')

# Title and labels with white font color for contrast
plt.title('Top 10 Games with the Most Streamers', fontsize=16, color='white')
plt.xlabel('Game', fontsize=12, color='white')
plt.ylabel('Total Streamers', fontsize=12, color='white')

# Set x-axis tick labels to rotate for better readability
plt.xticks(rotation=45, ha='right', color='white')

# Remove gridlines for a cleaner look
plt.grid(False)

# Tight layout to ensure elements fit well within the figure
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 2
#       1 # Group by 'Game' and sum the 'Streamers' for each game
# ----> 2 top_10_streamers = df_new.groupby('Game')['Streamers'].sum()
#       4 # Sort the games by the total 'Streamers' in descending order and get the top 10
#       5 top_10_streamers = top_10_streamers.sort_values(ascending=False).head(10)
#
# File /opt/anaconda3/envs/plotly_env/lib/python3.12/site-packages/pandas/core/frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
# ...

# %%
most_active_days = df_new['MOST_ACTIVE_DAY'].value_counts()

# Display the results in the console
print("Most Active Days:")
print(most_active_days)

# Streamlit app title
st.title("Most Active Days")

# Display the bar chart of most active days
st.bar_chart(most_active_days)
# Out:
# Most Active Days:
# MOST_ACTIVE_DAY
# Tuesday      183
# Wednesday    176
# Thursday     144
# Saturday     132
# Sunday       129
# Monday       118
# Friday       117
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 8
#       5 print(most_active_days)
#       7 # Streamlit app title
# ----> 8 st.title("Most Active Days")
#      10 # Display the bar chart of most active days
#      11 st.bar_chart(most_active_days)
#
# NameError: name 'st' is not defined

# %%
# Scatter plot to analyze how language affects followers gained per stream
plt.figure(figsize=(10, 6))
sns.boxplot(x='LANGUAGE', y='FOLLOWERS_GAINED_PER_STREAM', data=df_new, palette='Set2')
plt.title('Followers Gained Per Stream by Language')
plt.xlabel('Language')
plt.ylabel('Followers Gained Per Stream')
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_22560/1917249779.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='LANGUAGE', y='FOLLOWERS_GAINED_PER_STREAM', data=df_new, palette='Set2')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the custom order for the days of the week
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Step 1: Analyze MOST_ACTIVE_DAY
active_day_counts = df_new['MOST_ACTIVE_DAY'].value_counts()
active_day_counts = active_day_counts[days_order]  # Reorder counts based on days_order

# Step 2: Analyze DAY_WITH_MOST_FOLLOWERS_GAINED
followers_day_counts = df_new['DAY_WITH_MOST_FOLLOWERS_GAINED'].value_counts()
followers_day_counts = followers_day_counts[days_order]  # Reorder counts based on days_order

# Step 3: Plot the results
plt.figure(figsize=(12, 6))

# Subplot 1: Most Active Days
plt.subplot(1, 2, 1)
sns.barplot(x=active_day_counts.index, y=active_day_counts.values, palette='coolwarm')
plt.title('Most Active Days', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45)

# Subplot 2: Days with Most Followers Gained
plt.subplot(1, 2, 2)
sns.barplot(x=followers_day_counts.index, y=followers_day_counts.values, palette='coolwarm')
plt.title('Days with Most Followers Gained', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3735036014.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=active_day_counts.index, y=active_day_counts.values, palette='coolwarm')
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3735036014.py:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=followers_day_counts.index, y=followers_day_counts.values, palette='coolwarm')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort by total followers to get the top 10 streamers
top_streamers = df_new.nlargest(10, 'TOTAL_FOLLOWERS')

plt.figure(figsize=(10, 6))
sns.barplot(x='TOTAL_FOLLOWERS', y='NAME', data=top_streamers, palette='viridis')
plt.title('Top 10 Streamers by Total Followers')
plt.xlabel('Total Followers')
plt.ylabel('Streamer Name')
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3807358166.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='TOTAL_FOLLOWERS', y='NAME', data=top_streamers, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the dataframe by 'TOTAL_FOLLOWERS' to get the top 100 streamers
top_100_streamers = df_new.nlargest(100, 'TOTAL_FOLLOWERS')

# Count the number of streamers for each language in the top 100
language_counts = top_100_streamers['LANGUAGE'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(language_counts, labels=language_counts.index, autopct='%1.1f%%', 
        colors=sns.color_palette('viridis', len(language_counts)), startangle=140)

# Add title
plt.title('Languages Used by Top 100 Streamers', fontsize=16)

# Show the pie chart
plt.tight_layout()
plt.show()

# %%
# Sort the dataframe by 'TOTAL_FOLLOWERS' to get the top 1000 streamers
top_1000_streamers = df_new.nlargest(1000, 'TOTAL_FOLLOWERS')

# Count the number of streamers for each language in the top 1000
language_counts_1000 = top_1000_streamers['LANGUAGE'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(language_counts_1000, labels=language_counts_1000.index, autopct='%1.1f%%', 
        colors=sns.color_palette('viridis', len(language_counts_1000)), startangle=140)

# Add title
plt.title('Languages Used by Top 1000 Streamers', fontsize=16)

# Show the pie chart
plt.tight_layout()
plt.show()

# %%
# Step 1: Extract the most active days for all streamers
active_days_all_streamers = df_new['MOST_ACTIVE_DAY']

# Step 2: Count the occurrences of each active day
active_day_counts = active_days_all_streamers.value_counts()

# Step 3: Plot the most active days for all streamers
plt.figure(figsize=(8, 6))
sns.barplot(x=active_day_counts.index, y=active_day_counts.values, palette='coolwarm')

# Add titles and labels
plt.title('Most Active Days for 1000 Streamers', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Number of Streamers', fontsize=12)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3876599420.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=active_day_counts.index, y=active_day_counts.values, palette='coolwarm')

# %%
# Step 1: Identify the top 3 languages
top_5_languages = df_new['LANGUAGE'].value_counts().head(5).index

# Step 2: Filter the data to include only rows with these top 3 languages
filtered_data = df_new[df_new['LANGUAGE'].isin(top_5_languages)]

# Step 3: Convert 'MOST_ACTIVE_DAY' to a categorical type with the correct order (Monday to Sunday)
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
filtered_data['MOST_ACTIVE_DAY'] = pd.Categorical(filtered_data['MOST_ACTIVE_DAY'], categories=days_order, ordered=True)

# Step 4: Count the occurrences of each language by day of the week
language_day_counts = filtered_data.groupby(['MOST_ACTIVE_DAY', 'LANGUAGE']).size().reset_index(name='count')

# Step 5: Plot the data
plt.figure(figsize=(10, 6))
sns.barplot(x='MOST_ACTIVE_DAY', y='count', hue='LANGUAGE', data=language_day_counts, palette='coolwarm')

# Add titles and labels
plt.title('Top 3 Languages Streamed by Day of the Week', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Number of Streamers', fontsize=12)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3520085450.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['MOST_ACTIVE_DAY'] = pd.Categorical(filtered_data['MOST_ACTIVE_DAY'], categories=days_order, ordered=True)
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3520085450.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   language_day_counts = filtered_data.groupby(['MOST_ACTIVE_DAY', 'LANGUAGE']).size().reset_index(name='count')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Extract the most active days for all streamers
active_days_all_streamers = df_new['MOST_ACTIVE_DAY']

# Step 2: Convert to a categorical type with the correct order (Monday to Sunday)
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
active_days_all_streamers = pd.Categorical(active_days_all_streamers, categories=days_order, ordered=True)

# Step 3: Count the occurrences of each active day
active_day_counts = active_days_all_streamers.value_counts()

# Step 4: Plot the most active days for all streamers
plt.figure(figsize=(8, 6))
sns.barplot(x=active_day_counts.index, y=active_day_counts.values, palette='coolwarm')

# Add titles and labels
plt.title('Most Active Days for 1000 Streamers', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Number of Streamers', fontsize=12)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/3001258067.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=active_day_counts.index, y=active_day_counts.values, palette='coolwarm')

# %%
just_chatting = df_new[df_new["MOST_STREAMED_GAME"] == "Just Chatting"]
other_games = df_new[df_new["MOST_STREAMED_GAME"] != "Just Chatting"]

# Sort by RANK as a proxy for time progression
just_chatting = just_chatting.sort_values("RANK")
other_games = other_games.sort_values("RANK")

# Calculate cumulative views as a trend metric
just_chatting["CUMULATIVE_VIEWS"] = just_chatting["TOTAL_VIEWS"].cumsum()
other_games["CUMULATIVE_VIEWS"] = other_games["TOTAL_VIEWS"].cumsum()

# Plot the trend
plt.figure(figsize=(12, 6))
plt.plot(just_chatting["RANK"], just_chatting["CUMULATIVE_VIEWS"], label="Just Chatting", marker='o')
plt.plot(other_games["RANK"], other_games["CUMULATIVE_VIEWS"], label="Other Games", marker='o')

# Customize the plot
plt.title("Trend of Just Chatting vs Other Games Over Rank", fontsize=16)
plt.xlabel("Rank (Proxy for Time Progression)", fontsize=12)
plt.ylabel("Cumulative Views", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
df_new['FOLLOWER_GROWTH_RATE'] = df_new['FOLLOWERS_GAINED_PER_STREAM'] / df_new['TOTAL_TIME_STREAMED']
top_growth_accounts = df_new.sort_values(by='FOLLOWER_GROWTH_RATE', ascending=False).head(10)
print("\nTop 10 Accounts by Follower Growth Rate:")
print(top_growth_accounts[['NAME', 'FOLLOWER_GROWTH_RATE']])
# Out:
# Top 10 Accounts by Follower Growth Rate:
#                         NAME  FOLLOWER_GROWTH_RATE
# 31            legendus_shaka            235.242857
# 204                  jcorko_            208.717949
# 12          kato_junichi0817             81.492537
# 273  ilrossopiubelloditwitch             79.280000
# 661                    cinna             79.259259
# 758              bigbossboze             76.785714
# 340            pequenocabelo             67.270000
# 831                agustin51             64.555556
# 913              tonyrobbins             62.111111
# 516               zerospoker             55.841584

# %%
languages_to_include = ['English', 'Spanish']
filtered_data = df_new[df_new['LANGUAGE'].isin(languages_to_include)]

# Step 2: Convert 'MOST_ACTIVE_DAY' to a categorical type with the correct order (Monday to Sunday)
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
filtered_data['MOST_ACTIVE_DAY'] = pd.Categorical(filtered_data['MOST_ACTIVE_DAY'], categories=days_order, ordered=True)

# Step 3: Count the occurrences of each language by day of the week
language_day_counts = filtered_data.groupby(['MOST_ACTIVE_DAY', 'LANGUAGE']).size().reset_index(name='count')

# Step 4: Plot the data
plt.figure(figsize=(10, 6))
sns.barplot(x='MOST_ACTIVE_DAY', y='count', hue='LANGUAGE', data=language_day_counts, palette='coolwarm')

# Add titles and labels
plt.title('English vs Spanish Streamers by Day of the Week', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Number of Streamers', fontsize=12)
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/888020754.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['MOST_ACTIVE_DAY'] = pd.Categorical(filtered_data['MOST_ACTIVE_DAY'], categories=days_order, ordered=True)
# /var/folders/qh/x4phc7lj3cncffrbgl7xmf2r0000gn/T/ipykernel_45629/888020754.py:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   language_day_counts = filtered_data.groupby(['MOST_ACTIVE_DAY', 'LANGUAGE']).size().reset_index(name='count')
